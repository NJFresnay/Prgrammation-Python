# %%
import pandas as pd

# %%
Meteo = pd.read_csv(".//isd-history.csv", sep=",", index_col=0)

# %%
Meteo
# Out:
#          WBAN                   STATION NAME CTRY   ST  CALL     LAT     LON  \
# USAF
# 007018  99999                     WXPOD 7018  NaN  NaN   NaN   0.000   0.000
# 007026  99999                     WXPOD 7026   AF  NaN   NaN   0.000   0.000
# 007070  99999                     WXPOD 7070   AF  NaN   NaN   0.000   0.000
# 008260  99999                      WXPOD8270  NaN  NaN   NaN   0.000   0.000
# 008268  99999                      WXPOD8278   AF  NaN   NaN  32.950  65.567
# ...       ...                            ...  ...  ...   ...     ...     ...
# A07355    241      VIROQUA MUNICIPAL AIRPORT   US   WI  KY51  43.579 -90.913
# A07357    182  ELBOW LAKE MUNICIPAL PRIDE OF   US   MN  KY63  45.986 -95.992
# A07359    240           IONIA COUNTY AIRPORT   US   MI  KY70  42.938 -85.061
# A51255    445    DEMOPOLIS MUNICIPAL AIRPORT   US   AL  KDYA  32.464 -87.954
# A51256    451  BRANSON WEST MUNICIPAL EMERSO   US   MO  KFWB  36.699 -93.402
#
#         ELEV(M)     BEGIN       END
# ...

# %%
len(Meteo)
# Out:
# 29705

# %%
Lat = pd.cut(Meteo["LAT"], [Meteo["LAT"].min()-1, 0, Meteo["LAT"].max()+1], right=False)

# %%
Meteo.groupby(Lat)["WBAN"].count()
# Out:
# LAT
# [-91.0, 0.0)     4449
# [0.0, 84.65)    24052
# Name: WBAN, dtype: int64

# %%
Meteo[ Meteo["LAT"].isna() ]["WBAN"].count()
# Out:
# 1204

# %%
Meteo["BEGIN"] = pd.to_datetime(Meteo["BEGIN"], format='%Y%m%d')
Meteo["END"] = pd.to_datetime(Meteo["END"], format='%Y%m%d')

# %%
Meteo.head(5)
# Out:
#          WBAN STATION NAME CTRY   ST CALL    LAT     LON  ELEV(M)      BEGIN  \
# USAF
# 007018  99999   WXPOD 7018  NaN  NaN  NaN   0.00   0.000   7018.0 2011-03-09
# 007026  99999   WXPOD 7026   AF  NaN  NaN   0.00   0.000   7026.0 2012-07-13
# 007070  99999   WXPOD 7070   AF  NaN  NaN   0.00   0.000   7070.0 2014-09-23
# 008260  99999    WXPOD8270  NaN  NaN  NaN   0.00   0.000      0.0 2005-01-01
# 008268  99999    WXPOD8278   AF  NaN  NaN  32.95  65.567   1156.7 2010-05-19
#
#               END
# USAF
# 007018 2013-07-30
# 007026 2017-08-22
# 007070 2015-09-26
# 008260 2010-07-31
# 008268 2012-03-23

# %%
Meteo["ACT"] = Meteo["END"]-Meteo["BEGIN"]

# %%
Meteo.head(10)
# Out:
#          WBAN STATION NAME CTRY   ST CALL    LAT     LON  ELEV(M)      BEGIN  \
# USAF
# 007018  99999   WXPOD 7018  NaN  NaN  NaN   0.00   0.000   7018.0 2011-03-09
# 007026  99999   WXPOD 7026   AF  NaN  NaN   0.00   0.000   7026.0 2012-07-13
# 007070  99999   WXPOD 7070   AF  NaN  NaN   0.00   0.000   7070.0 2014-09-23
# 008260  99999    WXPOD8270  NaN  NaN  NaN   0.00   0.000      0.0 2005-01-01
# 008268  99999    WXPOD8278   AF  NaN  NaN  32.95  65.567   1156.7 2010-05-19
# 008307  99999   WXPOD 8318   AF  NaN  NaN   0.00   0.000   8318.0 2010-04-21
# 008411  99999         XM20  NaN  NaN  NaN    NaN     NaN      NaN 2016-02-17
# 008414  99999         XM18  NaN  NaN  NaN    NaN     NaN      NaN 2016-02-16
# 008415  99999         XM21  NaN  NaN  NaN    NaN     NaN      NaN 2016-02-17
# 008418  99999         XM24  NaN  NaN  NaN    NaN     NaN      NaN 2016-02-17
#
#               END       ACT
# USAF
# 007018 2013-07-30  874 days
# 007026 2017-08-22 1866 days
# ...

# %%
Meteo.sort_values("ACT", ascending=False)[ ["STATION NAME", "ACT"] ].head(10)
# Out:
#               STATION NAME        ACT
# USAF
# 029500  PARAINEN FAGERHOLM 43072 days
# 029810        PARAINEN UTO 43072 days
# 029070  KALAJOKI ULKOKALLA 43072 days
# 029720               TURKU 43072 days
# 228920              VYBORG 41246 days
# 028750                OULU 41246 days
# 029440    TAMPERE PIRKKALA 41246 days
# 029820       HANKO RUSSARO 41246 days
# 029170              KUOPIO 41246 days
# 028690             KUUSAMO 40150 days

# %%
GrpPays = Meteo.groupby("CTRY")
len(GrpPays["CTRY"])
# Out:
# 252

# %%
GrpPays["CTRY"].count().sort_values(ascending=False).head(1)
# Out:
# CTRY
# US    7320
# Name: CTRY, dtype: int64
